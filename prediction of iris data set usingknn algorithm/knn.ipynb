# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

path = (r"C:\Users\Leem\Downloads\iris.data")
headernames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
dataset = pd.read_csv(path, names = headernames)
dataset.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values
print(X)
print(y)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %%
    # Splitting the dataset into the Training set and Test set  
from sklearn.model_selection import train_test_split
train, test =train_test_split (dataset ,test_size = 0.40)

# %%
test.head()
# Out:
#      sepal-length  sepal-width  petal-length  petal-width            Class
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 13            4.3          3.0           1.1          0.1      Iris-setosa

# %%
train.head()
# Out:
#      sepal-length  sepal-width  petal-length  petal-width            Class
# 73            6.1          2.8           4.7          1.2  Iris-versicolor
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# 44            5.1          3.8           1.9          0.4      Iris-setosa
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 9             4.9          3.1           1.5          0.1      Iris-setosa

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size = 0.40)

# %%
X_train
# Out:
# array([[-1.31998504,  0.04352972, -1.25476109, -1.33693512],
#        [-0.32792948, -0.69103431,  0.63981971,  1.03009755],
#        [-1.31998504, -0.20132496, -1.36958417, -1.46843694],
#        [-1.19597809, -0.20132496, -1.36958417, -1.33693512],
#        [ 1.03614692,  0.04352972,  0.52499663,  0.37258848],
#        [-0.57594337,  2.00236714, -1.42699571, -1.07393149],
#        [-1.44399198,  0.2883844 , -1.42699571, -1.33693512],
#        [-1.07197115,  1.26780311, -1.36958417, -1.33693512],
#        [-1.94001976, -0.20132496, -1.54181879, -1.46843694],
#        [ 0.78813303, -0.20132496,  1.15652357,  1.29310118],
#        [ 0.78813303, -0.69103431,  0.46758509,  0.37258848],
#        [ 1.03614692, -0.20132496,  0.69723125,  0.63559211],
#        [ 2.27621637,  1.75751247,  1.67322742,  1.29310118],
#        [ 0.1680983 ,  0.77809375,  0.41017355,  0.50409029],
#        [ 1.5321747 , -0.20132496,  1.21393511,  1.16159937],
#        [ 0.54011914,  0.53323908,  0.52499663,  0.50409029],
#        [ 0.1680983 , -0.44617964,  0.41017355,  0.37258848],
#        [ 0.1680983 , -2.16016238,  0.12311586, -0.2849206 ],
#        [ 0.54011914, -0.93588899,  0.63981971,  0.76709392],
#        [-0.20392253, -0.69103431,  0.1805274 ,  0.10958485],
#        [-1.31998504, -0.20132496, -1.36958417, -1.20543331],
#        [-0.07991559, -0.93588899,  0.75464279,  0.89859574],
#        [-0.07991559, -0.93588899,  0.75464279,  0.89859574],
#        [ 1.78018859, -0.44617964,  1.44358126,  0.76709392],
#        [-0.20392253,  3.22664054, -1.31217263, -1.07393149],
#        [ 0.41611219,  0.77809375,  0.92687741,  1.424603  ],
#        [ 0.29210525, -0.69103431,  0.12311586,  0.10958485],
#        [ 2.15220942, -0.20132496,  1.61581588,  1.16159937],
#        [-1.07197115, -1.9153077 , -0.27876492, -0.2849206 ],
#        [-0.32792948, -1.42559835,  0.06570432, -0.15341878],
#        [ 0.66412608, -0.69103431,  1.04170049,  1.29310118],
#        [-0.57594337,  0.77809375, -1.19734955, -1.33693512],
#        [ 0.29210525, -0.20132496,  0.46758509,  0.24108666],
#        [-1.07197115,  0.77809375, -1.25476109, -1.07393149],
#        [ 1.28416081,  0.04352972,  0.63981971,  0.37258848],
#        [-0.57594337,  2.00236714, -1.19734955, -1.07393149],
#        [-0.20392253,  1.75751247, -1.19734955, -1.20543331],
#        [ 1.65618164,  0.2883844 ,  1.27134665,  0.76709392],
#        [-0.9479642 ,  1.02294843, -1.36958417, -1.33693512],
#        [ 0.04409136, -0.20132496,  0.23793894,  0.37258848],
#        [-1.31998504,  0.77809375, -1.25476109, -1.33693512],
#        [-0.45193642, -1.67045303,  0.00829278, -0.15341878],
#        [ 0.04409136,  0.2883844 ,  0.58240817,  0.76709392],
#        [ 0.41611219, -0.44617964,  0.29535048,  0.10958485],
#        [ 1.65618164,  1.26780311,  1.32875819,  1.68760663],
#        [-0.45193642,  2.73693118, -1.36958417, -1.33693512]])

# %%
dataset.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
len(X_test)
# Out:
# 60

# %%
len(y_test)
# Out:
# 60

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 8)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2)
# Out:
# Confusion Matrix:
# [[21  0  0]
#  [ 0 15  2]
#  [ 0  4 18]]
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        21
# Iris-versicolor       0.79      0.88      0.83        17
#  Iris-virginica       0.90      0.82      0.86        22
#
#        accuracy                           0.90        60
#       macro avg       0.90      0.90      0.90        60
#    weighted avg       0.90      0.90      0.90        60
#
# Accuracy: 0.9

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d91d9742edf2> in <module>
#       2 knnr = KNeighborsRegressor(n_neighbors = 10)
#       3 knnr.fit(X, y)
# ----> 4 print ("The MSE is:",format(np.power(y-knnr.predict(X),2).mean()))
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py in predict(self, X)
#     215
#     216         if weights is None:
# --> 217             y_pred = np.mean(_y[neigh_ind], axis=1)
#     218         else:
#     219             y_pred = np.empty((X.shape[0], _y.shape[1]), dtype=np.float64)
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3417             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3418
# -> 3419     return _methods._mean(a, axis=axis, dtype=dtype,
#    3420                           out=out, **kwargs)
#    3421
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     179     if isinstance(ret, mu.ndarray):
# --> 180         ret = um.true_divide(
#     181                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     182         if is_float16_result and out is None:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
